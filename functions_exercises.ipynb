# %% [markdown]
# ## Functions

# %% [markdown]
# ### Exercises!

# %% [markdown]
# Question
#
# Define a function that prints 'Hello, World!'.

# %%
### =====                ==== ####
###       YOUR CODE HERE      ####
### =====                ==== ####

# %% [markdown]
# Question
#
# Write a function that returns the company name given as input.

# %%
### =====                ==== ####
###       YOUR CODE HERE      ####
### =====                ==== ####

# %% [markdown]
# Question
#
# Write a function that returns the revenue after subtracting costs.

# %%
### =====                ==== ####
###       YOUR CODE HERE      ####
### =====                ==== ####

# %% [markdown]
# Question
#
# Write a function that formats an employee name into `'Lastname, Firstname'`.

# %%
### =====                ==== ####
###       YOUR CODE HERE      ####
### =====                ==== ####

# %% [markdown]
# Question
#
# Write a function with a default tax rate parameter that calculates net price.

# %%
### =====                ==== ####
###       YOUR CODE HERE      ####
### =====                ==== ####

# %% [markdown]
# Question
#
# Write a function that takes both positional and keyword arguments (e.g., `product`, `price`, `quantity`).

# %%
### =====                ==== ####
###       YOUR CODE HERE      ####
### =====                ==== ####

# %% [markdown]
# Question
#
# Write a function that computes average sales from a list.

# %%
### =====                ==== ####
###       YOUR CODE HERE      ####
### =====                ==== ####

# %% [markdown]
# Question
#
# Write a function that counts how many products in a list start with a certain letter.

# %%
### =====                ==== ####
###       YOUR CODE HERE      ####
### =====                ==== ####

# %% [markdown]
# Question
#
# Write a function that reads numbers from a file and returns the total.

# %%
### =====                ==== ####
###       YOUR CODE HERE      ####
### =====                ==== ####

# %% [markdown]
# Question
#
# Write a function that takes a string and returns it cleaned (lowercase, stripped).

# %%
### =====                ==== ####
###       YOUR CODE HERE      ####
### =====                ==== ####

# %% [markdown]
# Question
#
# Write a function with multiple return values: `(min_price, max_price)`.

# %%
### =====                ==== ####
###       YOUR CODE HERE      ####
### =====                ==== ####

# %% [markdown]
# Question
#
# Write a function to check if a customer is eligible for free shipping (purchase > threshold).

# %%
### =====                ==== ####
###       YOUR CODE HERE      ####
### =====                ==== ####

# %% [markdown]
# Question
#
# Write a function that logs errors to a file if given input is not a number.

# %%
### =====                ==== ####
###       YOUR CODE HERE      ####
### =====                ==== ####

# %% [markdown]
# Question
#
# Write a function that applies a discount depending on category (keyword arg).

# %%
### =====                ==== ####
###       YOUR CODE HERE      ####
### =====                ==== ####

# %% [markdown]
# Question
#
# Write a function that divides two numbers and handles division by zero.

# %%
### =====                ==== ####
###       YOUR CODE HERE      ####
### =====                ==== ####

# %% [markdown]
# Question
#
# Write a function that safely converts input to integer (with `try/except`).

# %%
### =====                ==== ####
###       YOUR CODE HERE      ####
### =====                ==== ####

# %% [markdown]
# Question
#
# Write a function that calculates ROI but raises an exception if investment = 0.

# %%
### =====                ==== ####
###       YOUR CODE HERE      ####
### =====                ==== ####

# %% [markdown]
# Question
#
# Write a function that asks the user for a number and keeps asking until correct input is provided.

# %%
### =====                ==== ####
###       YOUR CODE HERE      ####
### =====                ==== ####

# %% [markdown]
# Question
#
# Write a function that reads a CSV file and handles both `FileNotFoundError` and `ValueError`.

# %%
### =====                ==== ####
###       YOUR CODE HERE      ####
### =====                ==== ####

# %% [markdown]
# Question
#
# Write a function with `try/except/else/finally` for safe transaction processing.

# %%
### =====                ==== ####
###       YOUR CODE HERE      ####
### =====                ==== ####

# %% [markdown]
# Question
#
# Write a function that validates email format and raises `ValueError` if incorrect.

# %%
### =====                ==== ####
###       YOUR CODE HERE      ####
### =====                ==== ####

# %% [markdown]
# Question
#
# Recursive function to flatten a list of categories.

# %%
### =====                ==== ####
###       YOUR CODE HERE      ####
### =====                ==== ####

# %% [markdown]
# Question
#
# Recursive function that calculates the total discount applied over successive years.

# %%
### =====                ==== ####
###       YOUR CODE HERE      ####
### =====                ==== ####

# %% [markdown]
# Question
#
# Function that generates an acronym from a company name.

# %%
### =====                ==== ####
###       YOUR CODE HERE      ####
### =====                ==== ####

# %% [markdown]
# Question
#
# Function that counts word frequency in a text report.

# %%
### =====                ==== ####
###       YOUR CODE HERE      ####
### =====                ==== ####
